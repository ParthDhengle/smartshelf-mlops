# %%
import pandas as pd

# %%
pd.read_csv(r"C:/Users/parth/Desktop/Projects/MLOPS/smartshelf-mlops/data/raw/output_layer1/calendar.csv")
# Out:
#             date  day_of_week  month  quarter  year  is_weekend  season  \
# 0     2021-01-01            4      1        1  2021       False  Winter
# 1     2021-01-02            5      1        1  2021        True  Winter
# 2     2021-01-03            6      1        1  2021        True  Winter
# 3     2021-01-04            0      1        1  2021       False  Winter
# 4     2021-01-05            1      1        1  2021       False  Winter
# ...          ...          ...    ...      ...   ...         ...     ...
# 1456  2024-12-27            4     12        4  2024       False  Winter
# 1457  2024-12-28            5     12        4  2024        True  Winter
# 1458  2024-12-29            6     12        4  2024        True  Winter
# 1459  2024-12-30            0     12        4  2024       False  Winter
# 1460  2024-12-31            1     12        4  2024       False  Winter
#
#       is_holiday festival_name
# 0          False           NaN
# 1          False           NaN
# ...
